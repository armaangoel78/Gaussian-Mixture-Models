# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = np.linspace(-5,5, 1000)
y1 = stats.norm(-2, 5).pdf(x)
y2 = stats.norm(3.5, 2).pdf(x)

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y1+y2)

# %%
stats.norm(-2, 5).pdf(3)
# Out:
# 0.04839414490382867
